# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla=pdr.get_data_yahoo('TSLA')
df_tesla
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-09-27   23.432667   22.700001   23.326668   22.731333   90904500.0
# 2017-09-28   22.850000   22.360001   22.658667   22.639999   79794000.0
# 2017-09-29   22.978666   22.573334   22.790667   22.740000   76606500.0
# 2017-10-02   22.913334   22.367332   22.834667   22.768667   79302000.0
# 2017-10-03   23.236668   22.085333   22.393333   23.209333  152304000.0
# ...                ...         ...         ...         ...          ...
# 2022-09-21  313.799988  300.630005  308.290009  300.799988   62555700.0
# 2022-09-22  301.290009  285.820007  299.859985  288.589996   70545400.0
# 2022-09-23  284.500000  272.820007  283.089996  275.329987   63615400.0
# 2022-09-26  284.089996  270.309998  271.829987  276.010010   57927900.0
# 2022-09-27  284.869995  283.269989  271.829987  283.875000    2327475.0
#
#              Adj Close
# Date
# 2017-09-27   22.731333
# 2017-09-28   22.639999
# ...

# %%
#SIMPLE MOVING AVERAGE

# %%
df_tesla['Open'].plot(figsize= (15,8))

# %%
df_tesla['Open: 10 days rolling'] = df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla['Open: 10 days rolling']
# Out:
# Date
# 2017-09-27     23.326668
# 2017-09-28     22.992667
# 2017-09-29     22.925334
# 2017-10-02     22.902667
# 2017-10-03     22.800800
#                  ...
# 2022-09-21    297.555997
# 2022-09-22    299.411996
# 2022-09-23    298.553995
# 2022-09-26    295.664993
# 2022-09-27    293.557993
# Name: Open: 10 days rolling, Length: 1259, dtype: float64

# %%
df_tesla[['Open','Open: 10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))

# %%
df_tesla['Open: 30 days rolling'] = df_tesla['Open'].rolling(window=30,min_periods=1).mean()

# %%
df_tesla['Open: 40 days rolling'] = df_tesla['Open'].rolling(window=40,min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling','Open: 30 days rolling','Open: 40 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,15))

# %%
##CUMULATIVE MOVING AVG

# %%
df_tesla['Open'].expanding().mean().plot(figsize=(10,6))

# %%
# EWMA : Exponential weighted moving Average -> focus on recent data /current moving data

# %%
## EMA TESLA SHARES
# Let smoothing factor be = 0.1
df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,5))

# %%
df_tesla['EMA 5 days'] = df_tesla['Open'].ewm(span = 5).mean()

# %%
df_tesla[['Open','EMA 5 days']].plot(figsize=(15,8))
